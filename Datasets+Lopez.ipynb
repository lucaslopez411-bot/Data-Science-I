# %% [markdown]
# <a href="https://colab.research.google.com/github/lucaslopez411-bot/Data-Science-I/blob/main/Datasets%2BLopez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
csv_ventas = "https://raw.githubusercontent.com/lucaslopez411-bot/Data-Science-I/refs/heads/main/194%20-%20VENTAS%20-%20registros_ventas_comercio_online_diciembre_2024.csv"
csv_vuelos = "https://raw.githubusercontent.com/lucaslopez411-bot/Data-Science-I/refs/heads/main/dataset_vuelos.csv"

# %%
ventas_df = pd.read_csv(csv_ventas)
ventas_df.head(100)
# Out:
#         Fecha           Producto          Metodo de pago Tipo de Cliente  \
# 0   1/12/2024             Laptop  Transferencia Bancaria      Recurrente
# 1   2/12/2024         Accesorios  Transferencia Bancaria      Recurrente
# 2   3/12/2024  Reloj Inteligente  Transferencia Bancaria      Recurrente
# 3   4/12/2024             Laptop      Tarjeta de Credito      Recurrente
# 4   5/12/2024         Smartphone            Mercado Pago      Recurrente
# ..        ...                ...                     ...             ...
# 95  3/12/2024     Camara Digital      Tarjeta de Credito      Recurrente
# 96  4/12/2024             Tablet      Tarjeta de Credito      Recurrente
# 97  5/12/2024  Reloj Inteligente                  PayPal           Nuevo
# 98  6/12/2024         Smartphone            Mercado Pago      Recurrente
# 99  7/12/2024  Reloj Inteligente                  PayPal      Recurrente
#
#           Region     Metodo de Envio Estado del Pedido    Marca  \
# ...
